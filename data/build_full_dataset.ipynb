# %%
from datasets import load_from_disk
import matplotlib.pyplot as plt

# %%
fashion = load_from_disk("processed/african-fashion")
food = load_from_disk("processed/african-food")
# Out:
# Loading dataset from disk:   0%|          | 0/21 [00:00<?, ?it/s]

# %%
print(fashion)
# Out:
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 17368
# })

# %%
print(food)
# Out:
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 3195
# })

# %%
plt.figure(figsize=(10, 6))
plt.imshow(fashion[100]['image'])
plt.title(fashion[100]['label'])
plt.axis('off')
plt.show()

# %%
fashion[100]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=182x267>,
#  'label': 'Adire'}

# %%
plt.figure(figsize=(8, 6))
plt.imshow(food[10]['image'])
plt.title(food[10]['label'])
plt.axis('off')
plt.show()
